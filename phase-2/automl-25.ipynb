# %%
from pycaret.classification import *
from sklearn.model_selection import train_test_split

import pandas as pd
import os

# %%
ROOT_DIR = "../data"
RANDOM_STATE = 42

train_data = pd.read_csv(os.path.join(ROOT_DIR, "preprocessing_train.csv"))

df_normal = train_data[train_data["target"] == "Normal"]
df_abnormal = train_data[train_data["target"] == "AbNormal"]

normal_ratio = 1.2

num_normal = len(df_normal)
num_abnormal = len(df_abnormal)

## under sampling
df_normal = df_normal.sample(n=int(num_abnormal * normal_ratio), replace=False, random_state=RANDOM_STATE)
df_concat = pd.concat([df_normal, df_abnormal], axis=0).reset_index(drop=True)

train_data = df_concat

# df_train, df_val = train_test_split(
#     df_concat,
#     test_size=0.3,
#     stratify=df_concat["target"],
#     random_state=RANDOM_STATE,
# )

# %%
setup_clf = setup(data=train_data, target="target", train_size=0.7, session_id=333, fold_shuffle=True)
# Out:
# <style type="text/css">
# #T_a4500_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a4500">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4500_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a4500_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4500_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4500_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a4500_row0_col1" class="data row0 col1" >333</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4500_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a4500_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4500_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a4500_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4500_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_a4500_row3_col1" class="data row3 col1" >AbNormal: 0, Normal: 1</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4500_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_a4500_row4_col1" class="data row4 col1" >(5170, 146)</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a4500_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_a4500_row5_col1" class="data row5 col1" >(5170, 170)</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a4500_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_a4500_row6_col1" class="data row6 col1" >(3618, 170)</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a4500_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_a4500_row7_col1" class="data row7 col1" >(1552, 170)</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a4500_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_a4500_row8_col1" class="data row8 col1" >133</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a4500_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_a4500_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a4500_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_a4500_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a4500_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_a4500_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a4500_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_a4500_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a4500_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_a4500_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a4500_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_a4500_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a4500_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_a4500_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a4500_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_a4500_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a4500_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_a4500_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a4500_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_a4500_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a4500_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_a4500_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a4500_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_a4500_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a4500_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_a4500_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a4500_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a4500_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_a4500_row22_col1" class="data row22 col1" >f827</td>
#     </tr>
#   </tbody>
# </table>

# %%
ridge_model = create_model('ridge')
# Out:
# <style type="text/css">
# #T_7f403_row10_col0, #T_7f403_row10_col1, #T_7f403_row10_col2, #T_7f403_row10_col3, #T_7f403_row10_col4, #T_7f403_row10_col5, #T_7f403_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7f403">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f403_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7f403_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7f403_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7f403_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7f403_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7f403_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7f403_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f403_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f403_row0_col0" class="data row0 col0" >0.6271</td>
#       <td id="T_7f403_row0_col1" class="data row0 col1" >0.6417</td>
#       <td id="T_7f403_row0_col2" class="data row0 col2" >0.6271</td>
#       <td id="T_7f403_row0_col3" class="data row0 col3" >0.6250</td>
#       <td id="T_7f403_row0_col4" class="data row0 col4" >0.6249</td>
#       <td id="T_7f403_row0_col5" class="data row0 col5" >0.2415</td>
#       <td id="T_7f403_row0_col6" class="data row0 col6" >0.2424</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f403_row1_col0" class="data row1 col0" >0.6105</td>
#       <td id="T_7f403_row1_col1" class="data row1 col1" >0.6184</td>
#       <td id="T_7f403_row1_col2" class="data row1 col2" >0.6105</td>
#       <td id="T_7f403_row1_col3" class="data row1 col3" >0.6073</td>
#       <td id="T_7f403_row1_col4" class="data row1 col4" >0.6030</td>
#       <td id="T_7f403_row1_col5" class="data row1 col5" >0.1994</td>
#       <td id="T_7f403_row1_col6" class="data row1 col6" >0.2034</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f403_row2_col0" class="data row2 col0" >0.6133</td>
#       <td id="T_7f403_row2_col1" class="data row2 col1" >0.6359</td>
#       <td id="T_7f403_row2_col2" class="data row2 col2" >0.6133</td>
#       <td id="T_7f403_row2_col3" class="data row2 col3" >0.6101</td>
#       <td id="T_7f403_row2_col4" class="data row2 col4" >0.6074</td>
#       <td id="T_7f403_row2_col5" class="data row2 col5" >0.2072</td>
#       <td id="T_7f403_row2_col6" class="data row2 col6" >0.2102</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f403_row3_col0" class="data row3 col0" >0.6188</td>
#       <td id="T_7f403_row3_col1" class="data row3 col1" >0.6209</td>
#       <td id="T_7f403_row3_col2" class="data row3 col2" >0.6188</td>
#       <td id="T_7f403_row3_col3" class="data row3 col3" >0.6164</td>
#       <td id="T_7f403_row3_col4" class="data row3 col4" >0.6126</td>
#       <td id="T_7f403_row3_col5" class="data row3 col5" >0.2193</td>
#       <td id="T_7f403_row3_col6" class="data row3 col6" >0.2230</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f403_row4_col0" class="data row4 col0" >0.6077</td>
#       <td id="T_7f403_row4_col1" class="data row4 col1" >0.6408</td>
#       <td id="T_7f403_row4_col2" class="data row4 col2" >0.6077</td>
#       <td id="T_7f403_row4_col3" class="data row4 col3" >0.6053</td>
#       <td id="T_7f403_row4_col4" class="data row4 col4" >0.6050</td>
#       <td id="T_7f403_row4_col5" class="data row4 col5" >0.2022</td>
#       <td id="T_7f403_row4_col6" class="data row4 col6" >0.2033</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7f403_row5_col0" class="data row5 col0" >0.6243</td>
#       <td id="T_7f403_row5_col1" class="data row5 col1" >0.6792</td>
#       <td id="T_7f403_row5_col2" class="data row5 col2" >0.6243</td>
#       <td id="T_7f403_row5_col3" class="data row5 col3" >0.6222</td>
#       <td id="T_7f403_row5_col4" class="data row5 col4" >0.6182</td>
#       <td id="T_7f403_row5_col5" class="data row5 col5" >0.2306</td>
#       <td id="T_7f403_row5_col6" class="data row5 col6" >0.2345</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7f403_row6_col0" class="data row6 col0" >0.6022</td>
#       <td id="T_7f403_row6_col1" class="data row6 col1" >0.6184</td>
#       <td id="T_7f403_row6_col2" class="data row6 col2" >0.6022</td>
#       <td id="T_7f403_row6_col3" class="data row6 col3" >0.5995</td>
#       <td id="T_7f403_row6_col4" class="data row6 col4" >0.5990</td>
#       <td id="T_7f403_row6_col5" class="data row6 col5" >0.1902</td>
#       <td id="T_7f403_row6_col6" class="data row6 col6" >0.1914</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7f403_row7_col0" class="data row7 col0" >0.6685</td>
#       <td id="T_7f403_row7_col1" class="data row7 col1" >0.7156</td>
#       <td id="T_7f403_row7_col2" class="data row7 col2" >0.6685</td>
#       <td id="T_7f403_row7_col3" class="data row7 col3" >0.6674</td>
#       <td id="T_7f403_row7_col4" class="data row7 col4" >0.6654</td>
#       <td id="T_7f403_row7_col5" class="data row7 col5" >0.3245</td>
#       <td id="T_7f403_row7_col6" class="data row7 col6" >0.3270</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7f403_row8_col0" class="data row8 col0" >0.5817</td>
#       <td id="T_7f403_row8_col1" class="data row8 col1" >0.6053</td>
#       <td id="T_7f403_row8_col2" class="data row8 col2" >0.5817</td>
#       <td id="T_7f403_row8_col3" class="data row8 col3" >0.5774</td>
#       <td id="T_7f403_row8_col4" class="data row8 col4" >0.5758</td>
#       <td id="T_7f403_row8_col5" class="data row8 col5" >0.1437</td>
#       <td id="T_7f403_row8_col6" class="data row8 col6" >0.1457</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7f403_row9_col0" class="data row9 col0" >0.6066</td>
#       <td id="T_7f403_row9_col1" class="data row9 col1" >0.6448</td>
#       <td id="T_7f403_row9_col2" class="data row9 col2" >0.6066</td>
#       <td id="T_7f403_row9_col3" class="data row9 col3" >0.6034</td>
#       <td id="T_7f403_row9_col4" class="data row9 col4" >0.6013</td>
#       <td id="T_7f403_row9_col5" class="data row9 col5" >0.1952</td>
#       <td id="T_7f403_row9_col6" class="data row9 col6" >0.1977</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7f403_row10_col0" class="data row10 col0" >0.6161</td>
#       <td id="T_7f403_row10_col1" class="data row10 col1" >0.6421</td>
#       <td id="T_7f403_row10_col2" class="data row10 col2" >0.6161</td>
#       <td id="T_7f403_row10_col3" class="data row10 col3" >0.6134</td>
#       <td id="T_7f403_row10_col4" class="data row10 col4" >0.6113</td>
#       <td id="T_7f403_row10_col5" class="data row10 col5" >0.2154</td>
#       <td id="T_7f403_row10_col6" class="data row10 col6" >0.2179</td>
#     </tr>
#     <tr>
#       <th id="T_7f403_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7f403_row11_col0" class="data row11 col0" >0.0212</td>
#       <td id="T_7f403_row11_col1" class="data row11 col1" >0.0312</td>
#       <td id="T_7f403_row11_col2" class="data row11 col2" >0.0212</td>
#       <td id="T_7f403_row11_col3" class="data row11 col3" >0.0220</td>
#       <td id="T_7f403_row11_col4

# %%
tuned_ridge_model = tune_model(
    ridge_model,
    search_library='scikit-learn',  # 기본 설정
    search_algorithm='grid',  # 하이퍼파라미터 탐색 방법 ('grid' 또는 'random')
    custom_grid={'alpha': [0.1, 1.0, 10.0, 100.0,200.0, 500,0]}  # 하이퍼파라미터 'alpha' 값 설정
)
# Out:
# <style type="text/css">
# #T_12aeb_row10_col0, #T_12aeb_row10_col1, #T_12aeb_row10_col2, #T_12aeb_row10_col3, #T_12aeb_row10_col4, #T_12aeb_row10_col5, #T_12aeb_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_12aeb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12aeb_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_12aeb_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_12aeb_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_12aeb_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_12aeb_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_12aeb_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_12aeb_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12aeb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12aeb_row0_col0" class="data row0 col0" >0.6160</td>
#       <td id="T_12aeb_row0_col1" class="data row0 col1" >0.6560</td>
#       <td id="T_12aeb_row0_col2" class="data row0 col2" >0.6160</td>
#       <td id="T_12aeb_row0_col3" class="data row0 col3" >0.6131</td>
#       <td id="T_12aeb_row0_col4" class="data row0 col4" >0.6093</td>
#       <td id="T_12aeb_row0_col5" class="data row0 col5" >0.2116</td>
#       <td id="T_12aeb_row0_col6" class="data row0 col6" >0.2154</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12aeb_row1_col0" class="data row1 col0" >0.6022</td>
#       <td id="T_12aeb_row1_col1" class="data row1 col1" >0.6316</td>
#       <td id="T_12aeb_row1_col2" class="data row1 col2" >0.6022</td>
#       <td id="T_12aeb_row1_col3" class="data row1 col3" >0.5985</td>
#       <td id="T_12aeb_row1_col4" class="data row1 col4" >0.5956</td>
#       <td id="T_12aeb_row1_col5" class="data row1 col5" >0.1837</td>
#       <td id="T_12aeb_row1_col6" class="data row1 col6" >0.1868</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12aeb_row2_col0" class="data row2 col0" >0.6492</td>
#       <td id="T_12aeb_row2_col1" class="data row2 col1" >0.6654</td>
#       <td id="T_12aeb_row2_col2" class="data row2 col2" >0.6492</td>
#       <td id="T_12aeb_row2_col3" class="data row2 col3" >0.6478</td>
#       <td id="T_12aeb_row2_col4" class="data row2 col4" >0.6436</td>
#       <td id="T_12aeb_row2_col5" class="data row2 col5" >0.2804</td>
#       <td id="T_12aeb_row2_col6" class="data row2 col6" >0.2848</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12aeb_row3_col0" class="data row3 col0" >0.6409</td>
#       <td id="T_12aeb_row3_col1" class="data row3 col1" >0.6198</td>
#       <td id="T_12aeb_row3_col2" class="data row3 col2" >0.6409</td>
#       <td id="T_12aeb_row3_col3" class="data row3 col3" >0.6426</td>
#       <td id="T_12aeb_row3_col4" class="data row3 col4" >0.6298</td>
#       <td id="T_12aeb_row3_col5" class="data row3 col5" >0.2586</td>
#       <td id="T_12aeb_row3_col6" class="data row3 col6" >0.2689</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12aeb_row4_col0" class="data row4 col0" >0.6409</td>
#       <td id="T_12aeb_row4_col1" class="data row4 col1" >0.6547</td>
#       <td id="T_12aeb_row4_col2" class="data row4 col2" >0.6409</td>
#       <td id="T_12aeb_row4_col3" class="data row4 col3" >0.6394</td>
#       <td id="T_12aeb_row4_col4" class="data row4 col4" >0.6356</td>
#       <td id="T_12aeb_row4_col5" class="data row4 col5" >0.2653</td>
#       <td id="T_12aeb_row4_col6" class="data row4 col6" >0.2692</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_12aeb_row5_col0" class="data row5 col0" >0.6602</td>
#       <td id="T_12aeb_row5_col1" class="data row5 col1" >0.6925</td>
#       <td id="T_12aeb_row5_col2" class="data row5 col2" >0.6602</td>
#       <td id="T_12aeb_row5_col3" class="data row5 col3" >0.6588</td>
#       <td id="T_12aeb_row5_col4" class="data row5 col4" >0.6577</td>
#       <td id="T_12aeb_row5_col5" class="data row5 col5" >0.3086</td>
#       <td id="T_12aeb_row5_col6" class="data row5 col6" >0.3104</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_12aeb_row6_col0" class="data row6 col0" >0.5967</td>
#       <td id="T_12aeb_row6_col1" class="data row6 col1" >0.6431</td>
#       <td id="T_12aeb_row6_col2" class="data row6 col2" >0.5967</td>
#       <td id="T_12aeb_row6_col3" class="data row6 col3" >0.5932</td>
#       <td id="T_12aeb_row6_col4" class="data row6 col4" >0.5908</td>
#       <td id="T_12aeb_row6_col5" class="data row6 col5" >0.1748</td>
#       <td id="T_12aeb_row6_col6" class="data row6 col6" >0.1774</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_12aeb_row7_col0" class="data row7 col0" >0.6602</td>
#       <td id="T_12aeb_row7_col1" class="data row7 col1" >0.7343</td>
#       <td id="T_12aeb_row7_col2" class="data row7 col2" >0.6602</td>
#       <td id="T_12aeb_row7_col3" class="data row7 col3" >0.6624</td>
#       <td id="T_12aeb_row7_col4" class="data row7 col4" >0.6515</td>
#       <td id="T_12aeb_row7_col5" class="data row7 col5" >0.3003</td>
#       <td id="T_12aeb_row7_col6" class="data row7 col6" >0.3097</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_12aeb_row8_col0" class="data row8 col0" >0.6177</td>
#       <td id="T_12aeb_row8_col1" class="data row8 col1" >0.6357</td>
#       <td id="T_12aeb_row8_col2" class="data row8 col2" >0.6177</td>
#       <td id="T_12aeb_row8_col3" class="data row8 col3" >0.6156</td>
#       <td id="T_12aeb_row8_col4" class="data row8 col4" >0.6088</td>
#       <td id="T_12aeb_row8_col5" class="data row8 col5" >0.2129</td>
#       <td id="T_12aeb_row8_col6" class="data row8 col6" >0.2187</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_12aeb_row9_col0" class="data row9 col0" >0.6482</td>
#       <td id="T_12aeb_row9_col1" class="data row9 col1" >0.6761</td>
#       <td id="T_12aeb_row9_col2" class="data row9 col2" >0.6482</td>
#       <td id="T_12aeb_row9_col3" class="data row9 col3" >0.6478</td>
#       <td id="T_12aeb_row9_col4" class="data row9 col4" >0.6409</td>
#       <td id="T_12aeb_row9_col5" class="data row9 col5" >0.2768</td>
#       <td id="T_12aeb_row9_col6" class="data row9 col6" >0.2832</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_12aeb_row10_col0" class="data row10 col0" >0.6332</td>
#       <td id="T_12aeb_row10_col1" class="data row10 col1" >0.6609</td>
#       <td id="T_12aeb_row10_col2" class="data row10 col2" >0.6332</td>
#       <td id="T_12aeb_row10_col3" class="data row10 col3" >0.6319</td>
#       <td id="T_12aeb_row10_col4" class="data row10 col4" >0.6264</td>
#       <td id="T_12aeb_row10_col5" class="data row10 col5" >0.2473</td>
#       <td id="T_12aeb_row10_col6" class="data row10 col6" >0.2524</td>
#     </tr>
#     <tr>
#       <th id="T_12aeb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_12aeb_row11_col0" class="data row11 col0" >0.0221</td>
#       <td id="T_12aeb_row11_col1" class="data row11 col1" >0.0319</td>
#       <td id="T_12aeb_row11_col2" class="data row11 col2" >0.0221</td>
#       <td id="T_12aeb_row11_col3" class="data row11 col3" >0.0236</td>
#       <td id="T_12aeb_row11_col4
# Fitting 10 folds for each of 7 candidates, totalling 70 fits

# %%
tuned_ridge_model
# Out:
# RidgeClassifier(alpha=100.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, positive=False, random_state=333, solver='auto',
#                 tol=0.0001)

# %%
final_model = finalize_model(tuned_ridge_model)
evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
test_data = pd.read_csv(os.path.join(ROOT_DIR, "preprocessing_test.csv"))

train_columns = train_data.columns
test_data = test_data[train_columns]

df_test_x = test_data.drop(columns=['target'])

# %%
test_pred = predict_model(final_model, data=df_test_x)
test_pred
# Out:
#           Equipment_Dam Model.Suffix_Dam Workorder_Dam  \
# 0      Dam dispenser #2      AJX75334501    3J1XF767-1
# 1      Dam dispenser #2      AJX75334501    4B1XD472-2
# 2      Dam dispenser #1      AJX75334501    3H1XE355-1
# 3      Dam dispenser #2      AJX75334501    3L1XA128-1
# 4      Dam dispenser #1      AJX75334501    4A1XA639-1
# ...                 ...              ...           ...
# 17356  Dam dispenser #2      AJX75334501    3K1XB597-1
# 17357  Dam dispenser #2      AJX75334501    4A1XB974-1
# 17358  Dam dispenser #1      AJX75334501    3L1XA998-1
# 17359  Dam dispenser #1      AJX75334501    3F1XC376-1
# 17360  Dam dispenser #1      AJX75334501    3J1XC756-1
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                      1000.0
# 1                                      1000.0
# 2                                       240.0
# 3                                      1000.0
# 4                                       240.0
# ...                                       ...
# 17356                                  1000.0
# 17357                                  1000.0
# 17358                                   240.0
# 17359                                   240.0
# 17360                                   240.0
#
#        CURE END POSITION Z Collect Result_Dam  \
# 0                                        12.5
# 1                                        12.5
# 2                                         2.5
# 3                                        12.5
# 4                                         2.5
# ...                                       ...
# 17356                                    12.5
# 17357                                    12.5
# 17358                                     2.5
# 17359                                     2.5
# 17360                                     2.5
#
#        CURE END POSITION Θ Collect Result_Dam  CURE SPEED Collect Result_Dam  \
# 0                                          90                             70
# 1                                          90                             70
# 2                                         -90                             70
# 3                                          90                             70
# 4                                         -90                             70
# ...                                       ...                            ...
# 17356                                      90                             70
# 17357                                      90                             70
# 17358                                     -90                             70
# 17359                                     -90                             70
# 17360                                     -90                             70
#
#        CURE START POSITION X Collect Result_Dam  \
# 0                                           280
# 1                                           280
# 2                                          1030
# 3                                           280
# 4                                          1030
# ...                                         ...
# 17356                                       280
# 17357                                       280
# 17358                                      1030
# 17359                                      1030
# 17360                                      1030
#
#        CURE START POSITION Θ Collect Result_Dam  \
# 0                                            90
# 1                                            90
# 2                                           -90
# 3                                            90
# 4                                           -90
# ...                                         ...
# 17356                                        90
# 17357                                        90
# 17358                                       -90
# 17359                                       -90
# 17360                                       -90
#
#        DISCHARGED SPEED OF RESIN Collect Result_Dam  ...  \
# 0                                                10  ...
# 1                                                16  ...
# 2                                                10  ...
# 3                                                10  ...
# 4                                                16  ...
# ...                                             ...  ...
# 17356                                            10  ...
# 17357                                            16  ...
# 17358                                            16  ...
# 17359                                            10  ...
# 17360                                            10  ...
#
#        Head Clean Position Z Collect Result_Fill2  \
# 0                                       91.800003
# 1                                       50.000000
# 2                                       91.800003
# 3                                       50.000000
# 4                                       50.000000
# ...                                           ...
# 17356                                   50.000000
# 17357                                   50.000000
# 17358                                   50.000000
# 17359                                   91.800003
# 17360                                   91.800003
#
#        Head Purge Position X Collect Result_Fill2  \
# 0                                      270.000000
# 1                                       91.800003
# 2                                      270.000000
# 3                                       91.800003
# 4                                       91.800003
# ...                                           ...
# 17356                                   91.800003
# 17357                                   91.800003
# 17358                                   91.800003
# 17359                                  270.000000
# 17360                                  270.000000
#
#        Head Purge Position Y Collect Result_Fill2  \
# 0                                              50
# 1                                             270
# 2                                              50
# 3                                             270
# 4                                             270
# ...                                           ...
# 17356                                         270
# 17357                                         270
# 17358                                         270
# 17359                                          50
# 17360                                          50
#
#        Head Purge Position Z Collect Result_Fill2  \
# 0                                              85
# 1                                              50
# 2                                              85
# 3                                              50
# 4                                              50
# ...                                           ...
# 17356                                          50
# 17357                                          50
# 17358                                          50
# 17359                                          85
# 17360                                          85
#
#        Machine Tact time Collect Result_Fill2  PalletID Collect Result_Fill2  \
# 0                                   19.799999                      13.000000
# 1                                   85.000000                      19.799999
# 2                                   19.700001                       1.000000
# 3                                   85.000000                      20.000000
# 4                                   85.000000                      19.799999
# ...                                       ...                            ...
# 17356                               85.000000                      19.500000
# 17357                               85.000000                      19.799999
# 17358                               85.000000                      20.500000
# 17359                               18.900000                       1.000000
# 17360                               19.299999                       2.000000
#
#        Production Qty Collect Result_Fill2  Receip No Collect Result_Fill2  \
# 0                                      195                               1
# 1                                       14                             256
# 2                                       98                               1
# 3                                       14                               0
# 4                                        1                             215
# ...                                    ...                             ...
# 17356                                   14                             131
# 17357                                   12                             279
# 17358                                    4                              66
# 17359                                  117                               1
# 17360                                   71                               1
#
#        WorkMode Collect Result_Fill2  prediction_label
# 0                                  0            Normal
# 1                                  1            Normal
# 2                                  0          AbNormal
# 3                                  1            Normal
# 4                                  1            Normal
# ...                              ...               ...
# 17356                              1            Normal
# 17357                              1            Normal
# 17358                              1            Normal
# 17359                              0          AbNormal
# 17360                              0            Normal
#
# [17361 rows x 146 columns]

# %%
df_sub = pd.read_csv("../data/submission.csv")
df_sub["target"] = test_pred["prediction_label"]
df_sub.to_csv("../data/automl/submission-26.csv", index=False)
