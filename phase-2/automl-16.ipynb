# %%
from pycaret.classification import *
from sklearn.model_selection import train_test_split

import pandas as pd
import os

# %%
ROOT_DIR = "../data"
RANDOM_STATE = 42

train_data = pd.read_csv(os.path.join(ROOT_DIR, "preprocessing_train.csv"))

df_normal = train_data[train_data["target"] == "Normal"]
df_abnormal = train_data[train_data["target"] == "AbNormal"]

normal_ratio = 1.0

num_normal = len(df_normal)
num_abnormal = len(df_abnormal)

## under sampling
df_normal = df_normal.sample(n=int(num_abnormal * normal_ratio), replace=False, random_state=RANDOM_STATE)
df_concat = pd.concat([df_normal, df_abnormal], axis=0).reset_index(drop=True)

train_data = df_concat

# df_train, df_val = train_test_split(
#     df_concat,
#     test_size=0.3,
#     stratify=df_concat["target"],
#     random_state=RANDOM_STATE,
# )

# %%
setup_clf = setup(data=train_data, target="target", train_size=0.6, session_id=333, fold_shuffle=True)
# Out:
# <style type="text/css">
# #T_c6e67_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c6e67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6e67_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c6e67_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6e67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6e67_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c6e67_row0_col1" class="data row0 col1" >333</td>
#     </tr>
#     <tr>
#       <th id="T_c6e67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6e67_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c6e67_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_c6e67_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
model = compare_models(sort='F1', n_select=5, probability_threshold=0.5)
# Out:
# <style type="text/css">
# #T_3c964 th {
#   text-align: left;
# }
# ...

# %%
tuned_model = [tune_model(i) for i in model]
# Out:
# <style type="text/css">
# #T_fe320_row10_col0, #T_fe320_row10_col1, #T_fe320_row10_col2, #T_fe320_row10_col3, #T_fe320_row10_col4, #T_fe320_row10_col5, #T_fe320_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fe320">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe320_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fe320_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fe320_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fe320_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fe320_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fe320_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fe320_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
tuned_model
# Out:
# [CustomProbabilityThresholdClassifier(alpha=6.96, class_weight=None,
#                                       classifier=RidgeClassifier(alpha=6.96,
#                                                                  class_weight=None,
#                                                                  copy_X=True,
#                                                                  fit_intercept=True,
#                                                                  max_iter=None,
#                                                                  positive=False,
#                                                                  random_state=333,
#                                                                  solver='auto',
#                                                                  tol=0.0001),
#                                       copy_X=True, fit_intercept=True,
#                                       max_iter=None, positive=False,
# ...

# %%
blended_soft = blend_models(estimator_list=tuned_model[:2],
                       method="hard",
                       optimize="F1")
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           22:22:04
# Status     . . . . . . . . . . . . . . . . . .   Finalizing Model
# Estimator  . . . . . . . . . . . . . . . . . .  Voting Classifier
# Processing:   0%|          | 0/6 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/hgjeong/Desktop/github/LG-Aimers-5th/.venv/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/Users/hgjeong/Desktop/github/LG-Aimers-5th/.venv/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
final_model = finalize_model(tuned_model[0])
evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
test_data = pd.read_csv(os.path.join(ROOT_DIR, "preprocessing_test.csv"))

train_columns = train_data.columns
test_data = test_data[train_columns]

df_test_x = test_data.drop(columns=['target'])

# %%
test_pred = predict_model(final_model, data=df_test_x)
test_pred
# Out:
#           Equipment_Dam Model.Suffix_Dam Workorder_Dam  \
# 0      Dam dispenser #2      AJX75334501    3J1XF767-1
# 1      Dam dispenser #2      AJX75334501    4B1XD472-2
# 2      Dam dispenser #1      AJX75334501    3H1XE355-1
# 3      Dam dispenser #2      AJX75334501    3L1XA128-1
# 4      Dam dispenser #1      AJX75334501    4A1XA639-1
# ...                 ...              ...           ...
# 17356  Dam dispenser #2      AJX75334501    3K1XB597-1
# 17357  Dam dispenser #2      AJX75334501    4A1XB974-1
# 17358  Dam dispenser #1      AJX75334501    3L1XA998-1
# 17359  Dam dispenser #1      AJX75334501    3F1XC376-1
# 17360  Dam dispenser #1      AJX75334501    3J1XC756-1
#
#        CURE END POSITION X Collect Result_Dam  \
# 0                                      1000.0
# 1                                      1000.0
# 2                                       240.0
# 3                                      1000.0
# 4                                       240.0
# ...

# %%
df_sub = pd.read_csv("../data/submission.csv")
df_sub["target"] = test_pred["prediction_label"]
df_sub.to_csv("../data/automl/submission-17.csv", index=False)
